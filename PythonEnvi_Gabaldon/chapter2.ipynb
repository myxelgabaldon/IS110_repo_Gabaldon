# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/ColabNotebooks/IS110_BPerformance_Gabaldon/PythonEnvi_Gabaldon/
# Out:
# [Errno 2] No such file or directory: '/content/drive/MyDrive/ColabNotebooks/IS110_BPerformance_Gabaldon/PythonEnvi_Gabaldon/PythonEnvi_Gabaldon/'
# /content

# %%
# !pwd
# Out:
# /content/drive/MyDrive/ColabNotebooks/IS110_BPerformance_Gabaldon/PythonEnvi_Gabaldon

# %% [markdown]
# Exercise 1

# %% [markdown]
# Write a program that uses input to prompt a user for their name and then welcomes them.

# %% [markdown]
# Enter your name: Chuck
#
# Hello Chuck

# %%
name = input("Enter your name: ")
print("Hello", name)
# Out:
# Enter your name: Chunk
# Hello Chunk

# %% [markdown]
# Exercise 2

# %% [markdown]
# Write a program to prompt the user for hours and rate per hour to compute gross pay.

# %% [markdown]
# Enter Hours: 35
#
# Enter Rate: 2.75
#
# Pay: 96.25

# %%
hours_str = input ("Enter Hours:")
rate_str = input ("Enter Rate:")

hours = float (hours_str)
rate = float (rate_str)
pay = hours * rate
print ("total pay:", pay)
# Out:
# Enter Hours:35
# Enter Rate:2.75
# total pay: 96.25

# %% [markdown]
# Exercise 3

# %% [markdown]
# Assume that we execute the following assignment statements:

# %% [markdown]
# width = 17
#
# height = 12.0

# %% [markdown]
# For each of the following expressions, write the value of the expression and the type (of the value of the expression).

# %%
width = 17
height = 12.0

valuea= width//2
print(valuea, type(valuea))

valueb= width//2.0
print(valueb, type(valueb))

valuec= height/3
print(valuec, type(valuec))

valued= 1+2*5
print(valued, type(valued))
# Out:
# 8 <class 'int'>
# 8.0 <class 'float'>
# 4.0 <class 'float'>
# 11 <class 'int'>

# %% [markdown]
# Exercise 4

# %% [markdown]
# Write a program that uses input to prompt a user for a number and then outputs the square of the number

# %% [markdown]
# Enter a number: 3
#
# The square of 3 is 9

# %%
number_str = input ("Enter a number:")
number = int(number_str)
squareofnumber = number ** 2
print (f"The square of {number_str} is {squareofnumber}")
# Out:
# Enter a number:3
# The square of 3 is 9

# %% [markdown]
# CHALLENGE

# %% [markdown]
# Write a program which prompts the user for a Celsius temperature, convert the temperature to Fahrenheit, and print out the converted temperature.

# %%
celsius_str = input ("Enter temperature in celsius: ")

celsius = float (celsius_str)

fahrenheit = (celsius * 9/5) + 32

print (f"{celsius} degrees Celsius is equal to {fahrenheit} degrees Fahrenheit")
# Out:
# Enter temperature in celsius: 9
# 9.0 degrees Celsius is equal to 48.2 degrees Fahrenheit
